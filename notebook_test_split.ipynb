# %%
import numpy as np
from soak_low_level import SOAKFold

# --- synthetic data ---
X = np.arange(9).reshape(-1, 1)
y = X.ravel()
subset_vec = np.array(['even' if x % 2 == 0 else 'odd' for x in X.ravel()])

# --- Initialize soak object ---
soak_obj = SOAKFold(n_splits=2)

# %%
for subset_value, category, X_train, y_train, X_test, y_test in soak_obj.split(X, y, subset_vec):
    print(f"subset: {subset_value:6s} --- category: {category:6s}")
    print(f"X_test: {X_test.ravel()}  --- y_test: {y_test}")
    print(f"X_train:", X_train.ravel(), " --- y_train:", y_train)
    print("-"*50)
# Out:
# subset: even   --- category: same
# X_test: [2 6 8]  --- y_test: [2 6 8]
# X_train: [0 4]  --- y_train: [0 4]
# --------------------------------------------------
# subset: even   --- category: other
# X_test: [2 6 8]  --- y_test: [2 6 8]
# X_train: [1 3 5 7]  --- y_train: [1 3 5 7]
# --------------------------------------------------
# subset: even   --- category: all
# X_test: [2 6 8]  --- y_test: [2 6 8]
# X_train: [0 4 1 3 5 7]  --- y_train: [0 4 1 3 5 7]
# --------------------------------------------------
# subset: even   --- category: same
# X_test: [0 4]  --- y_test: [0 4]
# X_train: [2 6 8]  --- y_train: [2 6 8]
# --------------------------------------------------
# subset: even   --- category: other
# X_test: [0 4]  --- y_test: [0 4]
# X_train: [1 3 5 7]  --- y_train: [1 3 5 7]
# --------------------------------------------------
# subset: even   --- category: all
# X_test: [0 4]  --- y_test: [0 4]
# X_train: [2 6 8 1 3 5 7]  --- y_train: [2 6 8 1 3 5 7]
# --------------------------------------------------
# subset: odd    --- category: same
# X_test: [1 7]  --- y_test: [1 7]
# X_train: [3 5]  --- y_train: [3 5]
# --------------------------------------------------
# subset: odd    --- category: other
# X_test: [1 7]  --- y_test: [1 7]
# X_train: [0 2 4 6 8]  --- y_train: [0 2 4 6 8]
# --------------------------------------------------
# subset: odd    --- category: all
# X_test: [1 7]  --- y_test: [1 7]
# X_train: [3 5 0 2 4 6 8]  --- y_train: [3 5 0 2 4 6 8]
# --------------------------------------------------
# subset: odd    --- category: same
# X_test: [3 5]  --- y_test: [3 5]
# X_train: [1 7]  --- y_train: [1 7]
# --------------------------------------------------
# subset: odd    --- category: other
# X_test: [3 5]  --- y_test: [3 5]
# X_train: [0 2 4 6 8]  --- y_train: [0 2 4 6 8]
# --------------------------------------------------
# subset: odd    --- category: all
# X_test: [3 5]  --- y_test: [3 5]
# X_train: [1 7 0 2 4 6 8]  --- y_train: [1 7 0 2 4 6 8]
# --------------------------------------------------
